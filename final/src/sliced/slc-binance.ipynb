# %%
import pandas as pd
import zipfile
from slicer import slice_ticks
import os

PATH = '../../ticks/binance/'
SYMBOLS = ['BTCUSDT', 'ETHUSDT']
FREQ = ['10s', '1min', '5min', '10min']

# %%
def read_file(symbol, zip_name, freq):
    filename = PATH + f'{symbol}/{zip_name}'
    print(f'reading \'{filename}\'... ', end='')
    extention = filename[-4:]
    if extention == '.zip':
        csv_name = zip_name.replace('.zip', '.csv')
        zf = zipfile.ZipFile(filename) 
        df = pd.read_csv(zf.open(csv_name), header=None)
    elif extention == '.csv':        
        df = pd.read_csv(filename)
    else:
        print('Unsupported extention')
        return None

    no_idx = len(df.columns) == 6
    if no_idx:
        df.columns = ['id', 'price', 'size', 'quote_size', 'timestamp', 'is_sell']
    else:
        df.columns = ['idx', 'id', 'price', 'size', 'quote_size', 'timestamp', 'is_sell']

    df.drop_duplicates(subset='id', ignore_index=True, inplace=True)
    df.timestamp = pd.to_datetime(df.timestamp, unit='ms')
    df['side'] = 1 - (2 * df.is_sell.astype('int'))
    if no_idx:
        df.drop(columns=['id', 'quote_size', 'is_sell'], inplace=True)
    else:
        df.drop(columns=['idx', 'id', 'quote_size', 'is_sell'], inplace=True)
        
    if isinstance(freq, str):
        res = slice_ticks(df, freq)
        print(res.shape)
        return res
    elif isinstance(freq, list):
        res = {}
        for f in freq:
            res[f] = slice_ticks(df, f)

        print([(f, *res[f].shape) for f in freq])
        return res
    else:
        print('Unsupported freq type')
        return None

# %%
# temp = read_file('BTCUSDT', 'BTCUSDT-427085758-427134169.csv', FREQ)
# temp = read_file('BTCUSDT', 'BTCUSDT-trades-2021-12-31.zip', FREQ)

# %%
for symbol in SYMBOLS:
    dfs = [read_file(symbol, f, FREQ) for f in os.listdir(PATH + symbol)]
    # files = [
    #     'BTCUSDT-trades-2021-12-31.zip',
    #     'BTCUSDT-trades-2021-12-31.zip'
    # ]
    # dfs = [read_file(symbol, f, FREQ) for f in files]
    for f in FREQ:
        dfs_f = [d1[f] for d1 in dfs]
        df_all = pd.concat(dfs_f, ignore_index=True, axis=0) if len(dfs_f) > 0 else pd.DataFrame()
        df_all.sort_values(by='time', ignore_index=True, inplace=True)
        filename = f'../../bars/binance-{symbol}-{f}.csv'
        print(f'writing output to \'{filename}\'')
        df_all.to_csv(filename, date_format='%Y-%m-%d %H:%M:%S', index=False)
# Out:
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-30.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-31.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-27.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-555823694-555823695.csv'... [('10s', 3, 14), ('1min', 2, 14), ('5min', 2, 14), ('10min', 2, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-26.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-488251057-488924797.csv'... [('10s', 2457, 14), ('1min', 411, 14), ('5min', 83, 14), ('10min', 42, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-18.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-30.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-24.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-477192555-477325345.csv'... [('10s', 553, 14), ('1min', 93, 14), ('5min', 20, 14), ('10min', 11, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-25.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-19.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-21.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-09.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-517439800-517446365.csv'... [('10s', 22, 14), ('1min', 5, 14), ('5min', 2, 14), ('10min', 2, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-08.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-20.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-22.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-532382597-532642990.csv'... [('10s', 727, 14), ('1min', 122, 14), ('5min', 26, 14), ('10min', 14, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-23.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-06.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-12.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-839279885-843238898.csv'... [('10s', 3646, 14), ('1min', 609, 14), ('5min', 123, 14), ('10min', 62, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-13.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-07.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-11.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-05.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-04.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-10.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-14.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-28.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-485428888-485665269.csv'... [('10s', 822, 14), ('1min', 138, 14), ('5min', 29, 14), ('10min', 15, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-29.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-01.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-15.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-03.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-17.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-16.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-02.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-21.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-469201388-469234186.csv'... [('10s', 114, 14), ('1min', 20, 14), ('5min', 5, 14), ('10min', 3, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-471331093-471378543.csv'... [('10s', 188, 14), ('1min', 33, 14), ('5min', 8, 14), ('10min', 5, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-20.zip'... [('10s', 4997, 14), ('1min', 833, 14), ('5min', 167, 14), ('10min', 84, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-637752062-637883289.csv'... [('10s', 272, 14), ('1min', 47, 14), ('5min', 11, 14), ('10min', 6, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05.zip'... [('10s', 264197, 14), ('1min', 44033, 14), ('5min', 8807, 14), ('10min', 4404, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01.zip'... [('10s', 267766, 14), ('1min', 44628, 14), ('5min', 8926, 14), ('10min', 4463, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-524621349-524621349.csv'... [('10s', 4, 14), ('1min', 1, 14), ('5min', 1, 14), ('10min', 1, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-481148451-481707884.csv'... [('10s', 680, 14), ('1min', 115, 14), ('5min', 24, 14), ('10min', 13, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-28.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-427085758-427134169.csv'... [('10s', 75, 14), ('1min', 14, 14), ('5min', 4, 14), ('10min', 3, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02.zip'... [('10s', 236341, 14), ('1min', 39394, 14), ('5min', 7882, 14), ('10min', 3943, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03.zip'... [('10s', 267211, 14), ('1min', 44536, 14), ('5min', 8908, 14), ('10min', 4455, 14)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-29.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# writing output to '../../bars/binance-BTCUSDT-10s.csv'
# writing output to '../../bars/binance-BTCUSDT-1min.csv'
# writing output to '../../bars/binance-BTCUSDT-5min.csv'
# writing output to '../../bars/binance-BTCUSDT-10min.csv'
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-07.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12-30.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12-31.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-06.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-10.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-04.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-05.zip'... [('10s', 264197, 14), ('1min', 44033, 14), ('5min', 8807, 14), ('10min', 4404, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-11.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-375620960-375620961.csv'... [('10s', 5, 14), ('1min', 2, 14), ('5min', 2, 14), ('10min', 2, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-01.zip'... [('10s', 267765, 14), ('1min', 44628, 14), ('5min', 8926, 14), ('10min', 4463, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-02.zip'... [('10s', 236341, 14), ('1min', 39394, 14), ('5min', 7882, 14), ('10min', 3943, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-328435019-328576174.csv'... [('10s', 822, 14), ('1min', 138, 14), ('5min', 29, 14), ('10min', 15, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-03.zip'... [('10s', 267211, 14), ('1min', 44536, 14), ('5min', 8908, 14), ('10min', 4455, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-27.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-26.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-18.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-24.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-30.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-25.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-19.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-21.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-09.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-275173034-275226511.csv'... [('10s', 75, 14), ('1min', 14, 14), ('5min', 4, 14), ('10min', 3, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-08.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-20.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-22.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-23.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-325981522-326200598.csv'... [('10s', 680, 14), ('1min', 115, 14), ('5min', 24, 14), ('10min', 13, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-12.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-06.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-07.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-13.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-05.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-11.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-10.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-04.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-14.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-28.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-29.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-15.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-01.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-315571685-315620383.csv'... [('10s', 114, 14), ('1min', 20, 14), ('5min', 5, 14), ('10min', 3, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-330510159-330980086.csv'... [('10s', 2457, 14), ('1min', 411, 14), ('5min', 83, 14), ('10min', 42, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-350130260-350136088.csv'... [('10s', 22, 14), ('1min', 5, 14), ('5min', 2, 14), ('10min', 2, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-17.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-03.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-02.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-16.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-360542963-360735987.csv'... [('10s', 728, 14), ('1min', 122, 14), ('5min', 26, 14), ('10min', 14, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-318209933-318248935.csv'... [('10s', 189, 14), ('1min', 33, 14), ('5min', 8, 14), ('10min', 5, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-323290979-323447694.csv'... [('10s', 553, 14), ('1min', 93, 14), ('5min', 20, 14), ('10min', 11, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-355354661-355362822.csv'... [('10s', 37, 14), ('1min', 7, 14), ('5min', 3, 14), ('10min', 2, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-08.zip'... [('10s', 267840, 14), ('1min', 44640, 14), ('5min', 8928, 14), ('10min', 4464, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-603994798-607076183.csv'... [('10s', 3645, 14), ('1min', 609, 14), ('5min', 123, 14), ('10min', 62, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-09.zip'... [('10s', 259200, 14), ('1min', 43200, 14), ('5min', 8640, 14), ('10min', 4320, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12-29.zip'... [('10s', 8640, 14), ('1min', 1440, 14), ('5min', 288, 14), ('10min', 144, 14)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-422257936-422321321.csv'... [('10s', 273, 14), ('1min', 47, 14), ('5min', 11, 14), ('10min', 6, 14)]
# writing output to '../../bars/binance-ETHUSDT-10s.csv'
# writing output to '../../bars/binance-ETHUSDT-1min.csv'
# writing output to '../../bars/binance-ETHUSDT-5min.csv'
# writing output to '../../bars/binance-ETHUSDT-10min.csv'
