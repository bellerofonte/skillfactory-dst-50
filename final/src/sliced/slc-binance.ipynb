# %%
import pandas as pd
import zipfile
from slicer import slice_ticks
import os

PATH = '../../ticks/binance/'
SYMBOLS = ['BTCUSDT', 'ETHUSDT']
FREQ = ['10s', '1min', '5min', '10min']

# %%
def read_file(symbol, zip_name, freq):
    filename = PATH + f'{symbol}/{zip_name}'
    print(f'reading \'{filename}\'... ', end='')
    extention = filename[-4:]
    if extention == '.zip':
        csv_name = zip_name.replace('.zip', '.csv')
        zf = zipfile.ZipFile(filename) 
        df = pd.read_csv(zf.open(csv_name), header=None)
    elif extention == '.csv':        
        df = pd.read_csv(filename)
    else:
        print('Unsupported extention')
        return None

    no_idx = len(df.columns) == 6
    if no_idx:
        df.columns = ['id', 'price', 'size', 'quote_size', 'timestamp', 'is_sell']
    else:
        df.columns = ['idx', 'id', 'price', 'size', 'quote_size', 'timestamp', 'is_sell']

    df.drop_duplicates(subset='id', ignore_index=True, inplace=True)
    df.timestamp = pd.to_datetime(df.timestamp, unit='ms')
    df['side'] = 1 - (2 * df.is_sell.astype('int'))
    if no_idx:
        df.drop(columns=['id', 'quote_size', 'is_sell'], inplace=True)
    else:
        df.drop(columns=['idx', 'id', 'quote_size', 'is_sell'], inplace=True)
        
    if isinstance(freq, str):
        res = slice_ticks(df, freq)
        print(res.shape)
        return res
    elif isinstance(freq, list):
        res = {}
        for f in freq:
            res[f] = slice_ticks(df, f)

        print([(f, *res[f].shape) for f in freq])
        return res
    else:
        print('Unsupported freq type')
        return None

# %%
# temp = read_file('BTCUSDT', 'BTCUSDT-427085758-427134169.csv', FREQ)
# temp = read_file('BTCUSDT', 'BTCUSDT-trades-2021-12-31.zip', FREQ)

# %%
for symbol in SYMBOLS:
    dfs = [read_file(symbol, f, FREQ) for f in os.listdir(PATH + symbol)]
    # files = [
    #     'BTCUSDT-trades-2021-12-31.zip',
    #     'BTCUSDT-trades-2021-12-31.zip'
    # ]
    # dfs = [read_file(symbol, f, FREQ) for f in files]
    for f in FREQ:
        dfs_f = [d1[f] for d1 in dfs]
        df_all = pd.concat(dfs_f, ignore_index=True, axis=0) if len(dfs_f) > 0 else pd.DataFrame()
        df_all.sort_values(by='time', ignore_index=True, inplace=True)
        filename = f'../../bars/binance-{symbol}-{f}.csv'
        print(f'writing output to \'{filename}\'')
        df_all.to_csv(filename, date_format='%Y-%m-%d %H:%M:%S', index=False)
# Out:
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-30.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-31.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-27.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-555823694-555823695.csv'... [('10s', 3, 18), ('1min', 2, 18), ('5min', 2, 18), ('10min', 2, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-26.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-488251057-488924797.csv'... [('10s', 2457, 18), ('1min', 411, 18), ('5min', 83, 18), ('10min', 42, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-18.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-30.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-24.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-477192555-477325345.csv'... [('10s', 553, 18), ('1min', 93, 18), ('5min', 20, 18), ('10min', 11, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-25.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-19.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-21.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-09.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-517439800-517446365.csv'... [('10s', 22, 18), ('1min', 5, 18), ('5min', 2, 18), ('10min', 2, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-08.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-20.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-22.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-532382597-532642990.csv'... [('10s', 727, 18), ('1min', 122, 18), ('5min', 26, 18), ('10min', 14, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-23.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-06.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-12.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-839279885-843238898.csv'... [('10s', 3646, 18), ('1min', 609, 18), ('5min', 123, 18), ('10min', 62, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-13.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-07.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-11.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-05.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-04.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-10.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-14.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-28.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-485428888-485665269.csv'... [('10s', 822, 18), ('1min', 138, 18), ('5min', 29, 18), ('10min', 15, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-29.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-01.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-15.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-03.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-17.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-16.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2022-01-02.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-21.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-469201388-469234186.csv'... [('10s', 114, 18), ('1min', 20, 18), ('5min', 5, 18), ('10min', 3, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-471331093-471378543.csv'... [('10s', 188, 18), ('1min', 33, 18), ('5min', 8, 18), ('10min', 5, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-20.zip'... [('10s', 4997, 18), ('1min', 833, 18), ('5min', 167, 18), ('10min', 84, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-637752062-637883289.csv'... [('10s', 272, 18), ('1min', 47, 18), ('5min', 11, 18), ('10min', 6, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05.zip'... [('10s', 264197, 18), ('1min', 44033, 18), ('5min', 8807, 18), ('10min', 4404, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01.zip'... [('10s', 267766, 18), ('1min', 44628, 18), ('5min', 8926, 18), ('10min', 4463, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-524621349-524621349.csv'... [('10s', 4, 18), ('1min', 1, 18), ('5min', 1, 18), ('10min', 1, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-481148451-481707884.csv'... [('10s', 680, 18), ('1min', 115, 18), ('5min', 24, 18), ('10min', 13, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-28.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-427085758-427134169.csv'... [('10s', 75, 18), ('1min', 14, 18), ('5min', 4, 18), ('10min', 3, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02.zip'... [('10s', 236341, 18), ('1min', 39394, 18), ('5min', 7882, 18), ('10min', 3943, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03.zip'... [('10s', 267211, 18), ('1min', 44536, 18), ('5min', 8908, 18), ('10min', 4455, 18)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-12-29.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# writing output to '../../bars/binance-BTCUSDT-10s.csv'
# writing output to '../../bars/binance-BTCUSDT-1min.csv'
# writing output to '../../bars/binance-BTCUSDT-5min.csv'
# writing output to '../../bars/binance-BTCUSDT-10min.csv'
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-07.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12-30.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12-31.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-06.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-10.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-04.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-05.zip'... [('10s', 264197, 18), ('1min', 44033, 18), ('5min', 8807, 18), ('10min', 4404, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-11.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-375620960-375620961.csv'... [('10s', 5, 18), ('1min', 2, 18), ('5min', 2, 18), ('10min', 2, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-01.zip'... [('10s', 267765, 18), ('1min', 44628, 18), ('5min', 8926, 18), ('10min', 4463, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-02.zip'... [('10s', 236341, 18), ('1min', 39394, 18), ('5min', 7882, 18), ('10min', 3943, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-328435019-328576174.csv'... [('10s', 822, 18), ('1min', 138, 18), ('5min', 29, 18), ('10min', 15, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-03.zip'... [('10s', 267211, 18), ('1min', 44536, 18), ('5min', 8908, 18), ('10min', 4455, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-27.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-26.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-18.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-24.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-30.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-25.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-19.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-21.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-09.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-275173034-275226511.csv'... [('10s', 75, 18), ('1min', 14, 18), ('5min', 4, 18), ('10min', 3, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-08.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-20.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-22.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-23.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-325981522-326200598.csv'... [('10s', 680, 18), ('1min', 115, 18), ('5min', 24, 18), ('10min', 13, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-12.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-06.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-07.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-13.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-05.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-11.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-10.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-04.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-14.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-28.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-29.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-15.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-01.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-315571685-315620383.csv'... [('10s', 114, 18), ('1min', 20, 18), ('5min', 5, 18), ('10min', 3, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-330510159-330980086.csv'... [('10s', 2457, 18), ('1min', 411, 18), ('5min', 83, 18), ('10min', 42, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-350130260-350136088.csv'... [('10s', 22, 18), ('1min', 5, 18), ('5min', 2, 18), ('10min', 2, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-17.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-03.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-02.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-01-16.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-360542963-360735987.csv'... [('10s', 728, 18), ('1min', 122, 18), ('5min', 26, 18), ('10min', 14, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-318209933-318248935.csv'... [('10s', 189, 18), ('1min', 33, 18), ('5min', 8, 18), ('10min', 5, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-323290979-323447694.csv'... [('10s', 553, 18), ('1min', 93, 18), ('5min', 20, 18), ('10min', 11, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-355354661-355362822.csv'... [('10s', 37, 18), ('1min', 7, 18), ('5min', 3, 18), ('10min', 2, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-08.zip'... [('10s', 267840, 18), ('1min', 44640, 18), ('5min', 8928, 18), ('10min', 4464, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-603994798-607076183.csv'... [('10s', 3645, 18), ('1min', 609, 18), ('5min', 123, 18), ('10min', 62, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-09.zip'... [('10s', 259200, 18), ('1min', 43200, 18), ('5min', 8640, 18), ('10min', 4320, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2021-12-29.zip'... [('10s', 8640, 18), ('1min', 1440, 18), ('5min', 288, 18), ('10min', 144, 18)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-422257936-422321321.csv'... [('10s', 273, 18), ('1min', 47, 18), ('5min', 11, 18), ('10min', 6, 18)]
# writing output to '../../bars/binance-ETHUSDT-10s.csv'
# writing output to '../../bars/binance-ETHUSDT-1min.csv'
# writing output to '../../bars/binance-ETHUSDT-5min.csv'
# writing output to '../../bars/binance-ETHUSDT-10min.csv'
