# %%
import pandas as pd
import zipfile
from slicer import slice_ticks
import os

PATH = '../../ticks/binance/'
SYMBOLS = ['BTCUSDT', 'ETHUSDT']
FREQ = ['10s', '1min', '5min', '10min']

# %%
def read_file(symbol, zip_name, freq):
    filename = PATH + f'{symbol}/{zip_name}'
    print(f'reading \'{filename}\'... ', end='')
    extention = filename[-4:]
    if extention == '.zip':
        csv_name = zip_name.replace('.zip', '.csv')
        zf = zipfile.ZipFile(filename) 
        df = pd.read_csv(zf.open(csv_name), header=None)
    elif extention == '.csv':        
        df = pd.read_csv(filename)
    else:
        print('Unsupported extention')
        return None

    no_idx = len(df.columns) == 6
    if no_idx:
        df.columns = ['id', 'price', 'size', 'quote_size', 'timestamp', 'is_sell']
    else:
        df.columns = ['idx', 'id', 'price', 'size', 'quote_size', 'timestamp', 'is_sell']

    df.drop_duplicates(subset='id', ignore_index=True, inplace=True)
    df.timestamp = pd.to_datetime(df.timestamp, unit='ms')
    df['side'] = 1 - (2 * df.is_sell.astype('int'))
    if no_idx:
        df.drop(columns=['id', 'quote_size', 'is_sell'], inplace=True)
    else:
        df.drop(columns=['idx', 'id', 'quote_size', 'is_sell'], inplace=True)
        
    if isinstance(freq, str):
        res = slice_ticks(df, freq)
        print(res.shape)
        return res
    elif isinstance(freq, list):
        res = {}
        for f in freq:
            res[f] = slice_ticks(df, f)

        print([(f, *res[f].shape) for f in freq])
        return res
    else:
        print('Unsupported freq type')
        return None

# %%
# temp = read_file('BTCUSDT', 'BTCUSDT-427085758-427134169.csv', FREQ)
# temp = read_file('BTCUSDT', 'BTCUSDT-trades-2021-12-31.zip', FREQ)

# %%
for symbol in SYMBOLS:
    # files = [
    #     'BTCUSDT-trades-2021-12-31.zip',
    #     'BTCUSDT-trades-2021-12-31.zip'
    # ]
    files = os.listdir(PATH + symbol)
    files.sort()
    dfs = [read_file(symbol, f, FREQ) for f in files]
    for f in FREQ:
        dfs_f = [d1[f] for d1 in dfs]
        df_all = pd.concat(dfs_f, ignore_index=True, axis=0) if len(dfs_f) > 0 else pd.DataFrame()
        df_all.sort_values(by='time', ignore_index=True, inplace=True)
        filename = f'../../bars/binance-{symbol}-{f}.csv'
        print(f'writing output to \'{filename}\'')
        df_all.to_csv(filename, date_format='%Y-%m-%d %H:%M:%S', index=False)

print('done')
# Out:
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-26.zip'... [('10s', 8639, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-01-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-20.zip'... [('10s', 8620, 19), ('1min', 1437, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-22.zip'... [('10s', 8607, 19), ('1min', 1435, 19), ('5min', 287, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-02-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-02.zip'... [('10s', 8281, 19), ('1min', 1381, 19), ('5min', 277, 19), ('10min', 139, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-03-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-04-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-05-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-06-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-07-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-08-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-09-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-10-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/BTCUSDT/BTCUSDT-trades-2021-11-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# ...
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-04-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-01.zip'... [('10s', 8463, 19), ('1min', 1411, 19), ('5min', 283, 19), ('10min', 142, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-28.zip'... [('10s', 8428, 19), ('1min', 1405, 19), ('5min', 281, 19), ('10min', 141, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-05-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-06-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-05.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-06.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-07.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-08.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-09.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-10.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-11.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-12.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-13.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-14.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-15.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-16.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-17.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-18.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-19.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-20.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-21.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-22.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-23.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-24.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-25.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-26.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-27.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-28.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-29.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-30.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-07-31.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-08-01.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-08-02.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-08-03.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# reading '../../ticks/binance/ETHUSDT/ETHUSDT-trades-2022-08-04.zip'... [('10s', 8640, 19), ('1min', 1440, 19), ('5min', 288, 19), ('10min', 144, 19)]
# writing output to '../../bars/binance-ETHUSDT-10s.csv'
# writing output to '../../bars/binance-ETHUSDT-1min.csv'
# writing output to '../../bars/binance-ETHUSDT-5min.csv'
# writing output to '../../bars/binance-ETHUSDT-10min.csv'
# done
